# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in /home/michal/anaconda3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash) (2.0.2)
# Requirement already satisfied: flask-compress in /home/michal/anaconda3/lib/python3.8/site-packages (from dash) (1.10.1)
# Requirement already satisfied: dash-table==5.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash) (5.5.0)
# Requirement already satisfied: Jinja2>=3.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: click>=7.1.2 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (8.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (2.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: six in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: brotli in /home/michal/anaconda3/lib/python3.8/site-packages (from flask-compress->dash) (1.0.9)
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
#      |████████████████████████████████| 75 kB 448 kB/s eta 0:00:01
# Requirement already satisfied: Flask>=1.0.4 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (2.0.2)
# Requirement already satisfied: flask-compress in /home/michal/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (1.10.1)
# Requirement already satisfied: plotly in /home/michal/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (5.5.0)
# Collecting dash_renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
#      |████████████████████████████████| 1.0 MB 329 kB/s eta 0:00:01
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
#      |████████████████████████████████| 3.5 MB 830 kB/s eta 0:00:01
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
#      |████████████████████████████████| 188 kB 833 kB/s eta 0:00:01
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
#      |████████████████████████████████| 1.8 MB 897 kB/s eta 0:00:01
# Requirement already satisfied: future in /home/michal/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /home/michal/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: brotli in /home/michal/anaconda3/lib/python3.8/site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: six in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly->dash==1.19.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly->dash==1.19.0) (8.0.1)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84022 sha256=c945565f3a7be59ce23dca59c1e31c750be0611fd20a28baf5b9acae786fa1ad
#   Stored in directory: /home/michal/.cache/pip/wheels/e7/27/2f/a9f9bf858843b5365bcb311a80f0b2379737caf4ec50b2ae3a
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527013 sha256=74c940c1b5a7e087a5877f9563c091f03e30c763b18013c78b05a3b26d016b58
#   Stored in directory: /home/michal/.cache/pip/wheels/e3/e6/0e/759ca580c568aad2436521fa6df67f53a141dc1ab8f040c4c7
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427845 sha256=238935345ebaf37f546cf9b7337f75a01f298d1240bfc960753c3a3c1e4384ac
#   Stored in directory: /home/michal/.cache/pip/wheels/8a/bc/a8/7ad1d354777cfe77413fd7a092e07d7cc82f88f98997f4c463
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014870 sha256=2048c40869b31a5d3e95461a05109567db5d5992443f6b1ad42ca52aaf0e322a
#   Stored in directory: /home/michal/.cache/pip/wheels/08/94/09/e11ba8ae5d97e1c8ff5be0ac1f7cf42642eec6ea94ed1e4b44
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839875 sha256=ece380f6777ce6ad43da45ff5248b07f7a6e3efbbcc2ff3e8d858ef769a7ef66
#   Stored in directory: /home/michal/.cache/pip/wheels/cc/1d/a0/720dcf854e410eddbe44f8434f4d3a6332fdd085178eeac4f9
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table
# Installing collected packages: dash-table, dash-renderer, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.1.0
#     Uninstalling dash-2.1.0:
#       Successfully uninstalled dash-2.1.0
# Successfully installed dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-renderer-1.9.0 dash-table-4.11.2
# Requirement already satisfied: jupyter_dash in /home/michal/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: dash in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ipython in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (7.29.0)
# Requirement already satisfied: ansi2html in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.7.0)
# Requirement already satisfied: requests in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (2.27.1)
# Requirement already satisfied: retrying in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipykernel in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (6.4.1)
# Requirement already satisfied: flask in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (2.0.2)
# Requirement already satisfied: plotly in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (5.5.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: future in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: flask-compress in /home/michal/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: click>=7.1.2 in /home/michal/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (8.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (2.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: brotli in /home/michal/anaconda3/lib/python3.8/site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: ipython-genutils in /home/michal/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: decorator in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (5.1.0)
# Requirement already satisfied: backcall in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (58.0.4)
# Requirement already satisfied: pickleshare in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: pygments in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (2.10.0)
# Requirement already satisfied: pexpect>4.3 in /home/michal/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/michal/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /home/michal/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/michal/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/michal/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/michal/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/michal/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: plotly in /home/michal/anaconda3/lib/python3.8/site-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.6.0-py2.py3-none-any.whl (27.7 MB)
#      |████████████████████████████████| 27.7 MB 963 kB/s eta 0:00:01
# Requirement already satisfied: tenacity>=6.2.0 in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /home/michal/anaconda3/lib/python3.8/site-packages (from plotly) (1.16.0)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.6.0

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px

# %%
# notebook hangs if I run the following command 
JupyterDash.infer_jupyter_proxy_config()

# %%
# needs to be run again in a separate cell due to a jupyterdash bug
JupyterDash.infer_jupyter_proxy_config()

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
#import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app

if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
